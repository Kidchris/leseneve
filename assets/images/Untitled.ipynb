# %%
import glob 
import os
from PIL import Image

# %%
images = []
listes = glob.glob('*.jpg')

# %%
listes
# Out:
# ['logo.jpg', 'Industrial-970x90-banner.jpg', 'Arhitecture9.jpg', 'baniere.jpg']

# %%
refait = listes.split('.jpg')

# %%
ima = Image.open('Site.png')
import matplotlib.pyplot as plt
import numpy as np

# %%
i  = np.array(ima)

# %%
plt.imshow(i)

# %%
plt.savefig(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-c49741c709e2> in <module>
# ----> 1 plt.savefig(i)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ...

# %%
images = []
for im  in range(len(listes)):
    image = Image.open(listes[im])
    images.append(image)
    refait = images[im].resize((1253, 853))
    print(refait.size)
    refait.save('{}'.format(listes[im]))
# Out:
# (1253, 853)
# (1253, 853)
# (1253, 853)
# (1253, 853)
